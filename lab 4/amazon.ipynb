# %%
#import pandas module for creating dataframe
import pandas as pd

#read CSV into DataFrame
data = pd.read_csv("k_Reviews.csv")
data
# Out:
#             Id   ProductId          UserId                    ProfileName  \
# 0       234341  B000VSFMCW  A131LUACH7MW2J                 Hasan T. Albar
# 1       507328  B003WYFDH6  A3HPGUIBONTSF8                            Amy
# 2        38885  B000V6HQPK  A34WVNI8LWVZEN  James P. Janulet "Jungle Jim"
# 3       233459  B0006GXLQS   AWC8CTW8N2XVE                   TheCommish16
# 4       331713  B000CL4GWU   ALGRQ8MUI5A7X                  Myra A. Mason
# ...        ...         ...             ...                            ...
# 568449  282517  B00292BM7C  A1I8P6I9FPT44G                           Anna
# 568450  282428  B00292BM7W  A2XTJRFTA5MH5V                     L. Preston
# 568451  282515  B00292BM7C  A2XTJRFTA5MH5V                     L. Preston
# 568452   20227  B002HGQ0YK  A2B051FJ0KUWDY                     D. Russick
# 568453   99758  B001ELLAH6  A20CTKKZEQGD3E       Akua Grant "Akua Rising"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
import re
import string

def get_cleaned_textdata(sentence):
    # Remove HTML tags
    modified_sentence = re.sub(r'<.*?>', ' ', sentence)
    
    # Remove punctuation
    modified_sentence = ''.join([i if i not in string.punctuation else ' ' for i in modified_sentence])
    
    # Remove digits
    modified_sentence = re.sub(r'\d', ' ', modified_sentence)
    
    # Remove extra whitespaces
    modified_sentence = re.sub(r'\s+', ' ', modified_sentence)
    
    # Convert to lowercase
    modified_sentence = modified_sentence.lower()
    
    return modified_sentence

# Example usage:
sentence = "This is a test sentence, with some <html>tag</html> and digits like 123."
cleaned_sentence = get_cleaned_textdata(sentence)
print(cleaned_sentence)
# Out:
# this is a test sentence with some tag and digits like

# %%
data
# Out:
#             Id   ProductId          UserId                    ProfileName  \
# 0       234341  B000VSFMCW  A131LUACH7MW2J                 Hasan T. Albar
# 1       507328  B003WYFDH6  A3HPGUIBONTSF8                            Amy
# 2        38885  B000V6HQPK  A34WVNI8LWVZEN  James P. Janulet "Jungle Jim"
# 3       233459  B0006GXLQS   AWC8CTW8N2XVE                   TheCommish16
# 4       331713  B000CL4GWU   ALGRQ8MUI5A7X                  Myra A. Mason
# ...        ...         ...             ...                            ...
# 568449  282517  B00292BM7C  A1I8P6I9FPT44G                           Anna
# 568450  282428  B00292BM7W  A2XTJRFTA5MH5V                     L. Preston
# 568451  282515  B00292BM7C  A2XTJRFTA5MH5V                     L. Preston
# 568452   20227  B002HGQ0YK  A2B051FJ0KUWDY                     D. Russick
# 568453   99758  B001ELLAH6  A20CTKKZEQGD3E       Akua Grant "Akua Rising"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def get_cleaned_textdata(sentence):
    # Remove HTML tags
    modified_sentence = re.sub(r'<.*?>', ' ', sentence)
    
    # Remove punctuation and special characters
    modified_sentence = ''.join([i if i not in string.punctuation else ' ' for i in modified_sentence])
    
    # Remove digits
    modified_sentence = re.sub(r'\d', ' ', modified_sentence)
    
    # Convert to lowercase
    modified_sentence = modified_sentence.lower()
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    modified_sentence = ' '.join([word for word in modified_sentence.split() if word not in stop_words])
    
    # Perform stemming
    stemmer = PorterStemmer()
    modified_sentence = ' '.join([stemmer.stem(word) for word in modified_sentence.split()])
    
    # Perform lemmatization
    lemmatizer = WordNetLemmatizer()
    modified_sentence = ' '.join([lemmatizer.lemmatize(word) for word in modified_sentence.split()])
    
    return modified_sentence

# Example usage:
sentence = "This is a test sentence, with some <html>tag</html> and digits like 123."
cleaned_sentence = get_cleaned_textdata(sentence)
print(cleaned_sentence)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# test sentenc tag digit like

# %%
data
# Out:
#             Id   ProductId          UserId                    ProfileName  \
# 0       234341  B000VSFMCW  A131LUACH7MW2J                 Hasan T. Albar
# 1       507328  B003WYFDH6  A3HPGUIBONTSF8                            Amy
# 2        38885  B000V6HQPK  A34WVNI8LWVZEN  James P. Janulet "Jungle Jim"
# 3       233459  B0006GXLQS   AWC8CTW8N2XVE                   TheCommish16
# 4       331713  B000CL4GWU   ALGRQ8MUI5A7X                  Myra A. Mason
# ...        ...         ...             ...                            ...
# 568449  282517  B00292BM7C  A1I8P6I9FPT44G                           Anna
# 568450  282428  B00292BM7W  A2XTJRFTA5MH5V                     L. Preston
# 568451  282515  B00292BM7C  A2XTJRFTA5MH5V                     L. Preston
# 568452   20227  B002HGQ0YK  A2B051FJ0KUWDY                     D. Russick
# 568453   99758  B001ELLAH6  A20CTKKZEQGD3E       Akua Grant "Akua Rising"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
import pandas as pd
import re
import string

def get_cleaned_textdata(sentence):
    # Remove HTML tags
    modified_sentence = re.sub(r'<.*?>', '', sentence)
    
    # Remove punctuation
    modified_sentence = ''.join([i if i not in string.punctuation else '' for i in modified_sentence])
    
    # Remove digits
    modified_sentence = re.sub(r'\d', '', modified_sentence)
    
    # Remove extra whitespaces
    modified_sentence = re.sub(r'\s+', ' ', modified_sentence)
    
    # Convert to lowercase
    modified_sentence = modified_sentence.lower()
    
    return modified_sentence

# Read the data from the Excel file
data = pd.read_csv("k_Reviews.csv")

# Remove duplicates based on the 'Text' column
text_column = data['Text'].drop_duplicates()

# Apply the cleaning function to the 'Text' column after removing duplicates
data['modified_sentence'] = text_column.apply(get_cleaned_textdata)

# Display the modified text column
print(data['modified_sentence'])
# Out:
# 0          just like the original one in saudi arabiaver...
# 1          item arrived in perfect condition and very qu...
# 2          ok getcher beer getcher minute rice and hotty...
# 3          been buying these for my cat for about a year...
# 4          better yet pods of caffeine bliss this variet...
#                                 ...
# 568449                                                  NaN
# 568450    zukes turkey n taterz mini bakes are a great p...
# 568451                                                  NaN
# 568452    zuma my hairless chinese crested pup is a very...
# 568453    zzzzzzz i had high hopes for this coffee and h...
# Name: modified_sentence, Length: 568454, dtype: object

# %%
data
# Out:
#             Id   ProductId          UserId                    ProfileName  \
# 0       234341  B000VSFMCW  A131LUACH7MW2J                 Hasan T. Albar
# 1       507328  B003WYFDH6  A3HPGUIBONTSF8                            Amy
# 2        38885  B000V6HQPK  A34WVNI8LWVZEN  James P. Janulet "Jungle Jim"
# 3       233459  B0006GXLQS   AWC8CTW8N2XVE                   TheCommish16
# 4       331713  B000CL4GWU   ALGRQ8MUI5A7X                  Myra A. Mason
# ...        ...         ...             ...                            ...
# 568449  282517  B00292BM7C  A1I8P6I9FPT44G                           Anna
# 568450  282428  B00292BM7W  A2XTJRFTA5MH5V                     L. Preston
# 568451  282515  B00292BM7C  A2XTJRFTA5MH5V                     L. Preston
# 568452   20227  B002HGQ0YK  A2B051FJ0KUWDY                     D. Russick
# 568453   99758  B001ELLAH6  A20CTKKZEQGD3E       Akua Grant "Akua Rising"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...
